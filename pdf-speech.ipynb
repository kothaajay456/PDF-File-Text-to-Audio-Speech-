# %% [markdown]
# <a href="https://colab.research.google.com/github/kothaajay456/PDF-File-Text-to-Audio-Speech-/blob/main/pdf-speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2 gTTS

import PyPDF2
from gtts import gTTS
from IPython.display import Audio

def pdf_to_speech(pdf_path):
    # Open the PDF file
    with open(pdf_path, 'rb') as file:
        # Create a PDF reader object
        reader = PyPDF2.PdfReader(file)

        # Initialize text variable to store extracted text
        text = ''

        # Iterate through each page in the PDF
        for page_num in range(len(reader.pages)):
            # Extract text from the page
            page = reader.pages[page_num]
            text += page.extract_text()

    # Convert text to speech
    tts = gTTS(text)

    # Save speech as an audio file
    audio_file = 'speech.mp3'
    tts.save(audio_file)

    # Display the audio file
    return Audio(audio_file)

# Provide the path to your PDF file
pdf_path = '/content/pdf-sample.pdf'

# Convert PDF to speech and play the audio
pdf_to_speech(pdf_path)
# Out:
# ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
